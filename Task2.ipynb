# %% [markdown]
# Problem 1: Unique Words in a Sentence

# %%
sentence = input("Enter sentence: ")

words = sentence.split()

unique_words = set(words)

print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)

# %% [markdown]
# Problem 2: Highest Salary from Employee Data

# %%
employees = {
    "Abhirami": 55000,
    "Guna": 72000,
    "Siddu": 55000
}

highest_employee = max(employees, key=employees.get)

print("Highest Salary:", highest_employee, "-", employees[highest_employee])

# %% [markdown]
# Problem 3: Find Maximum and Minimum Values

# %%
numbers = [49, 23, 79, 11, 64]

maximum = numbers[0]
minimum = numbers[0]

for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

print("List:", numbers)
print("Max:", maximum)
print("Min:", minimum)

# %% [markdown]
# Problem 4: Count Products Above a Price Threshold

# %%
prices = [530, 1340, 789, 1520, 1320]

count = 0

for price in prices:
    if price > 1000:
        count += 1

print("Products above 1000:", count)

# %% [markdown]
# Problem 5: Calculate Attendance Percentage

# %%
attendance = ["P", "A", "P", "A", "A"]

total_days = len(attendance)

present_count = 0

for day in attendance:
    if day == "P":
        present_count += 1

attendance_percentage = (present_count / total_days) * 100

print("Attendance Percentage:", attendance_percentage)

# %% [markdown]
# Problem 6: Remove Duplicate Phone Numbers

# %%
phone_numbers = [9701065201, 6303573430, 7709279997, 6281421214]

unique_numbers = set(phone_numbers)

print("Unique phone numbers:", unique_numbers)

# %% [markdown]
# Problem 7: Count Character Frequency

# %%
text = "Frequency"

char_count = {}
for ch in text:
    if ch in char_count:
        char_count[ch] += 1
    else:
        char_count[ch] = 1

print(char_count)

# %% [markdown]
# Problem 8: Convert List to Tuple

# %%
numbers = [20, 30, 40]

numbers_tuple = tuple(numbers)

print("Tuple:", numbers_tuple)

# %% [markdown]
# Problem 9: Check if a Key Exists in a Dictionary

# %%
employees = {
    "Abhirami": 25000,
    "Guna": 50000,
    "Vinod": 60000
}

key_to_check = "Ram"

if key_to_check in employees:
    print("Employee exists")
else:
    print("Employee does not exist")

# %% [markdown]
# Problem 10: Calculate Average Marks

# %%
marks = [55, 60, 95, 70]

total = sum(marks)

count = len(marks)

average = total / count

print("Average Marks:", average)
