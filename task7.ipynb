# %%
class SmartLight:

    def __init__(self, location):
        self.location = location
        self.mode = "OFF"

    def toggle(self, value):
        if value.upper() == "ON":
            self.mode = "ON"
        elif value.upper() == "OFF":
            self.mode = "OFF"

    def status(self):
        print(self.location, "light status:", self.mode)


light_obj = SmartLight("Study-Room")
light_obj.toggle("ON")
light_obj.status()
# Out:
# Study-Room light status: ON

# %%
class Employee:

    def __init__(self, emp_name, emp_code, section):
        self.emp_name = emp_name
        self.emp_code = emp_code
        self.section = section

    def display(self):
        print("Employee Details")
        print("Name:", self.emp_name)
        print("Code:", self.emp_code)
        print("Section:", self.section)


emp_obj = Employee("Hemanth", "EMP535", "QA")
emp_obj.display()
# Out:
# Employee Details
# Name: Hemanth
# Code: EMP535
# Section: QA

# %%
class Contact:

    def __init__(self, username, mobile):
        self.username = username
        self.mobile = mobile

    def show(self):
        print("Saved Contact")
        print("User:", self.username)
        print("Mobile:", self.mobile)


contact_obj = Contact("Ruthvik", 9015430245)
contact_obj.show()
# Out:
# Saved Contact
# User: Ruthvik
# Mobile: 9015430245

# %%
class Product:

    def __init__(self, product_name, amount):
        self.product_name = product_name
        self.amount = amount

    def generate_tag(self):
        print("Item:", self.product_name)
        print("Cost: ₹", self.amount)


product_obj = Product("Apple Tablet", 52899)
product_obj.generate_tag()
# Out:
# Item: Apple Tablet
# Cost: ₹ 52899

# %%
class Movie:

    def __init__(self, movie_name, rating_value):
        self.movie_name = movie_name
        self.rating_value = rating_value

    def display_rating(self):
        print("Movie Name:", self.movie_name)
        print("User Rating:", self.rating_value, "/5")


movie_obj = Movie("Jersey", 4.8)
movie_obj.display_rating()
# Out:
# Movie Name: Jersey
# User Rating: 4.8 /5

# %%
class DeliveryDetails:

    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def print_details(self):
        print("Delivery Details")
        print("Customer:", self.customer_name)
        print("Address:", self.address)


order1 = DeliveryDetails("Manohar", "Hyderabad")
order1.print_details()
# Out:
# Delivery Details
# Customer: Manohar
# Address: Hyderabad
